# %%
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import cfgrib
from tensorflow import keras
import cartopy.crs as ccrs
# Out:
# 2022-06-24 03:03:43.343903: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-24 03:03:43.343958: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# pip install scipy or pykdtree
ax = plt.axes(projection=ccrs.Mollweide())
ax.stock_img()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /opt/venv/lib/python3.10/site-packages/Cartopy-0.0.0-py3.10-linux-x86_64.egg/cartopy/img_transform.py in <module>
#      13 try:
# ---> 14     import pykdtree.kdtree
#      15     _is_pykdtree = True
#
# ModuleNotFoundError: No module named 'pykdtree'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# /opt/venv/lib/python3.10/site-packages/Cartopy-0.0.0-py3.10-linux-x86_64.egg/cartopy/img_transform.py in <module>
#      17     try:
# ---> 18         import scipy.spatial
#      19     except ImportError as e:
#
# ModuleNotFoundError: No module named 'scipy'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_779/2474856828.py in <cell line: 2>()
#       1 ax = plt.axes(projection=ccrs.Mollweide())
# ----> 2 ax.stock_img()
#       3 plt.show()
#
# /opt/venv/lib/python3.10/site-packages/Cartopy-0.0.0-py3.10-linux-x86_64.egg/cartopy/mpl/geoaxes.py in stock_img(self, name)
#    1062                                  '50-natural-earth-1-downsampled.png')
#    1063
# -> 1064             return self.imshow(imread(fname), origin='upper',
#    1065                                transform=source_proj,
#    1066                                extent=[-180, 180, -90, 90])
#
# /opt/venv/lib/python3.10/site-packages/Cartopy-0.0.0-py3.10-linux-x86_64.egg/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     316
#     317         kwargs['transform'] = transform
# --> 318         return func(self, *args, **kwargs)
#     319     return wrapper
#     320
#
# /opt/venv/lib/python3.10/site-packages/Cartopy-0.0.0-py3.10-linux-x86_64.egg/cartopy/mpl/geoaxes.py in imshow(self, img, *args, **kwargs)
#    1372             # Lazy import because scipy/pykdtree in img_transform are only
#    1373             # optional dependencies
# -> 1374             from cartopy.img_transform import warp_array
#    1375             original_extent = extent
#    1376             img, extent = warp_array(img,
#
# /opt/venv/lib/python3.10/site-packages/Cartopy-0.0.0-py3.10-linux-x86_64.egg/cartopy/img_transform.py in <module>
#      18         import scipy.spatial
#      19     except ImportError as e:
# ---> 20         raise ImportError("Using image transforms requires either "
#      21                           "pykdtree or scipy.") from e
#      22     _is_pykdtree = False
#
# ImportError: Using image transforms requires either pykdtree or scipy.

# %%
ax = plt.axes(projection=ccrs.Mollweide())
ax.stock_img()
plt.show()

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()

ny_lon, ny_lat = -75, 43
delhi_lon, delhi_lat = 77.23, 28.61

plt.plot(
    [ny_lon, delhi_lon],
    [ny_lat, delhi_lat],
    color="blue",
    linewidth=2,
    marker="o",
    transform=ccrs.Geodetic(),
)

plt.plot(
    [ny_lon, delhi_lon],
    [ny_lat, delhi_lat],
    color="gray",
    linestyle="--",
    transform=ccrs.PlateCarree(),
)

plt.text(ny_lon - 3, ny_lat - 12, "New York", horizontalalignment="right", transform=ccrs.Geodetic())

plt.text(delhi_lon + 3, delhi_lat - 12, "Delhi", horizontalalignment="left", transform=ccrs.Geodetic())

plt.show()
