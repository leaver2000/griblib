# %%
# %load_ext griblib.jupyter

from pathlib import Path
from warnings import warn
from datetime import datetime
from typing import Callable, Union, Iterable, Iterator, Literal, TypedDict

import pandas as pd
import numpy as np
import dask.dataframe as dd
from dask.dataframe.core import DataFrame as DaskDataFrame
from geopandas import GeoDataFrame
from requests import Session, HTTPError
from typing import Generic, TypeVar
from geopandas.base import GeometryArray
from geopandas import GeoSeries
import geopandas._vectorized as geov
import pygeos
from numpy.typing import NDArray

import xarray as xr
from shapely.geometry import GeometryCollection

import warnings
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>
# /opt/conda/envs/rapids/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   warnings.warn(

# %%
class Properties(TypedDict):
    MUCAPE: int
    MLCAPE: int
    MLCIN: int
    EBSHEAR: float
    SRH01KM: int
    MESH: float
    VIL_DENSITY: float
    FLASH_RATE: int
    FLASH_DENSITY: float
    MAXLLAZ: float
    P98LLAZ: float
    P98MLAZ: float
    MAXRC_EMISS: str
    MAXRC_ICECF: str
    WETBULB_0C_HGT: float
    PWAT: float
    CAPE_M10M30: int
    LJA: float
    SIZE: int
    AVG_BEAM_HGT: str
    MOTION_EAST: float
    MOTION_SOUTH: float
    PS: int
    ID: int


class Geometry(TypedDict):
    type: Literal["Polygon"]
    coordinates: list[list[tuple[float, float]]]


class Feature(TypedDict):
    type: Literal["Feature"]
    geometry: Geometry
    models: dict[str, dict[str, str]]
    properties: Properties


class FeatureCollection(TypedDict):
    source: Literal["NOAA/NCEP Central Operations"]
    product: Literal["ProbSevere"]
    type: Literal["FeatureCollection"]
    validTime: str
    productionTime: str
    machine: str
    features: list[Feature]


TimeLike = Union[datetime, str, pd.Timestamp]

# %%
import requests
import xarray as xr

VALIDTIME_TEMPLATE = "%Y%m%d_%H%M%S %Z"
FLOAT32_COLS = [
    "EBSHEAR",
    "MEANWIND_1-3kmAGL",
    "MESH",
    "VIL_DENSITY",
    "FLASH_DENSITY",
    "MOTION_EAST",
    "MOTION_SOUTH",
    "MAXLLAZ",
    "P98LLAZ",
    "P98MLAZ",
    "WETBULB_0C_HGT",
    "PWAT",
    "LJA",
]

INT32_COLS = ["MLCIN"]
UINT32_COLS = [
    "MUCAPE",
    "MLCAPE",
    "SRH01KM",
    "FLASH_RATE",
    "CAPE_M10M30",
    "SIZE",
    "ID",
]
UINT8_COLS = ["PS"]
ALL_COLUMNS = UINT8_COLS + UINT32_COLS + INT32_COLS + FLOAT32_COLS


def extract(date: TimeLike) -> Iterable[FeatureCollection]:
    base_url = "https://mtarchive.geol.iastate.edu"
    url = f"{base_url}/{date:%Y}/{date:%m}/{date:%d}/mrms/ncep/ProbSevere/"
    r = requests.get(url)
    if r.status_code == 200:
        (df,) = pd.read_html(r.text, skiprows=[1, 2], keep_default_na=False)

        with Session() as session:
            for file in tuple(url + df.loc[df["Name"] != "", "Name"]):
                try:
                    # with our session make a get request, r is a response object
                    r = session.get(file, stream=True)
                    # in the event of a non 200 status code we'll raise a HTTPError and trigger the except block
                    r.raise_for_status()
                # if there was an error downloading, continue
                except (ConnectionError, HTTPError):
                    warn(f"error downloading {url}")
                    continue
                yield r.json()


def _wrangle_geometry(df: GeoDataFrame) -> pd.DataFrame:
    # to keep things consistent uppercase all of the bounds
    bounds = df.bounds
    df[bounds.columns.str.upper()] = bounds
    with warnings.catch_warnings():
        # /opt/conda/envs/rapids/lib/python3.9/site-packages/geopandas/array.py:524:
        # ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
        #   return GeometryArray(vectorized.representative_point(self.data), crs=self.crs)
        warnings.simplefilter("ignore")
        points = df.representative_point()
    df["Y"] = points.x
    df["X"] = points.y
    return df


def update_dtypes(df: pd.DataFrame, float32: list[str], int32: list[str], uint32: list[str], uint8: list[str]):
    df[float32] = df[float32].astype(np.float32)
    # 32-bit signed integer (``-2_147_483_648`` to ``2_147_483_647``)
    df[int32] = df[int32].astype(np.int32)
    # 32-bit unsigned integer (``0`` to ``4_294_967_295``)
    df[uint32] = df[uint32].astype(np.uint32)
    # numpy.uint8`: 8-bit unsigned integer (``0`` to ``255``)
    df[uint8] = df[uint8].astype(np.uint8)
    return df


def transfer(data: Iterable[FeatureCollection]) -> xr.Dataset:
    keys = []

    def generate():
        for fc in data:
            keys.append(datetime.strptime(fc["validTime"], VALIDTIME_TEMPLATE))
            df = GeoDataFrame.from_features(fc["features"], columns=ALL_COLUMNS + ["geometry"])
            df["time"] = datetime.strptime(fc["validTime"], VALIDTIME_TEMPLATE)
            yield df

    df = pd.concat(generate()).set_index("time").pipe(_wrangle_geometry).drop(columns="geometry")

    df = update_dtypes(
        df,
        float32=FLOAT32_COLS + ["MINX", "MINY", "MAXX", "MAXY", "X", "Y"],
        int32=INT32_COLS,
        uint32=UINT32_COLS,
        uint8=UINT8_COLS,
    )
    return xr.Dataset.from_dataframe(df)


def load(ds: xr.Dataset, store: Path) -> None:
    zarr_kwargs = {}
    if store.exists():
        zarr_kwargs = {"mode": "a", "append_dim": "time"}
    ds.to_zarr(store, **zarr_kwargs)


def main():
    store = Path.cwd().parent / "data/PROBSEVERE"
    date = datetime.fromisoformat("2022-01-01")
    data = extract(date)
    ds = transfer(data)
    load(ds, store)


main()

# %%
xr.open_zarr(Path.cwd().parent / "data/PROBSEVERE").to_dataframe().set_index("ID", append=True)
# Out:
#                            CAPE_M10M30    EBSHEAR  FLASH_DENSITY  FLASH_RATE  \
# time                ID
# 2022-01-01 00:00:38 20964          207  49.700001           0.02           0
#                     21312          187  43.700001           0.00           0
#                     21320            0   0.000000           0.00           0
#                     21323          169  43.200001           0.00           0
#                     21324            0   0.000000           0.00           0
# ...                                ...        ...            ...         ...
# 2022-01-01 23:58:38 28342            0  27.000000           0.00           0
#                     28343           41  59.299999           0.00           0
#                     28344           85  61.799999           0.00           0
#                     28345          248  56.700001           0.00           0
#                     28346          478  65.599998           0.00           0
#
#                            LJA  MAXLLAZ        MAXX       MAXY  \
# time                ID
# 2022-01-01 00:00:38 20964  0.0    0.005  -83.879997  34.730000
#                     21312  0.0    0.004 -110.470001  32.799999
#                     21320  0.0    0.000  -71.029999  47.990002
#                     21323  0.0    0.001 -110.320000  32.939999
#                     21324  0.0    0.000  -95.980003  39.849998
# ...                        ...      ...         ...        ...
# 2022-01-01 23:58:38 28342  0.0    0.001  -88.330002  36.230000
#                     28343  0.0    0.004  -85.620003  35.849998
#                     28344  0.0    0.013  -85.669998  35.619999
#                     28345  0.0    0.002  -87.879997  34.840000
#                     28346  0.0    0.002  -93.120003  32.529999
#
#                            MEANWIND_1-3kmAGL  MESH  ...  P98LLAZ  P98MLAZ  PS  \
# time                ID                              ...
# 2022-01-01 00:00:38 20964          36.799999  0.04  ...    0.004    0.004   8
#                     21312          34.500000  0.00  ...    0.003    0.003   3
#                     21320          31.200001  0.18  ...    0.000    0.000   0
#                     21323          35.099998  0.00  ...    0.001    0.001   3
#                     21324          35.500000  0.27  ...    0.000    0.000   0
# ...                                      ...   ...  ...      ...      ...  ..
# 2022-01-01 23:58:38 28342          27.500000  0.00  ...    0.001    0.001   0
#                     28343          50.700001  0.00  ...    0.004    0.006   4
#                     28344          52.799999  0.03  ...    0.012    0.005   6
#                     28345          46.200001  0.00  ...    0.002    0.001   5
#                     28346          31.900000  0.00  ...    0.002    0.002   6
#
#                            PWAT  SIZE  SRH01KM  VIL_DENSITY  WETBULB_0C_HGT  \
# time                ID
# 2022-01-01 00:00:38 20964   1.4   306      200         0.79             9.1
#                     21312   0.7   128       85         0.37             4.2
#                     21320   0.3    68      168         0.94             0.4
#                     21323   0.7   135       84         0.41             3.5
#                     21324   0.4    69      150         0.51             0.3
# ...                         ...   ...      ...          ...             ...
# 2022-01-01 23:58:38 28342   1.4    45        0         0.38            11.3
#                     28343   1.6    49      170         1.01            10.9
#                     28344   1.6    43      289         1.21            10.0
#                     28345   1.8    46      171         0.24            11.3
#                     28346   1.7    43       93         0.50            10.8
#
#                                    X           Y
# time                ID
# 2022-01-01 00:00:38 20964  34.639999  -83.972504
#                     21312  32.709999 -110.526001
#                     21320  47.935001  -71.165001
#                     21323  32.884998 -110.385002
#                     21324  39.810001  -96.019997
# ...                              ...         ...
# 2022-01-01 23:58:38 28342  36.209999  -88.366669
#                     28343  35.825001  -85.654999
#                     28344  35.584999  -85.702499
#                     28345  34.820000  -87.918747
#                     28346  32.505001  -93.150002
#
# [47067 rows x 27 columns]

# %%
URL_TEMPLATE = "https://mtarchive.geol.iastate.edu/%Y/%m/%d/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_%Y%m%d_%H%M00.json"
VALIDTIME_TEMPLATE = "%Y%m%d_%H%M%S %Z"

def iterdaterange(
    start: TimeLike, end: TimeLike, *, freq: str = "2min"
) -> Iterator[tuple[pd.Timestamp, pd.DataFrame]]:

    dr = pd.date_range(start=start, end=end, freq=freq)
    urls = dr.strftime(URL_TEMPLATE)
    yield from pd.DataFrame({"date": dr, "urls": urls}).set_index(dr).groupby(pd.Grouper(key="date", freq="D", axis=0))


def generate_from_features(session: Session, *, urls: Iterable[str]) -> Iterable[pd.DataFrame]:
    for url in urls:
        try:
            # with our session make a get request, r is a response object
            r = session.get(url, stream=True)
            # in the event of a non 200 status code we'll raise a HTTPError and trigger the except block
            r.raise_for_status()
        # if there was an error downloading, continue
        except (ConnectionError, HTTPError):
            warn(f"error downloading {url}")
            continue
        fc: FeatureCollection = r.json()

        features = fc["features"]
        # in the event no storms were record, continue
        if not features:
            # geojson file contained no features
            continue

        df = GeoDataFrame.from_features(features)
        df["VALIDTIME"] = datetime.strptime(fc["validTime"], VALIDTIME_TEMPLATE)
        yield df


def wrangle_geometry(df: GeoDataFrame) -> pd.DataFrame:
    # to keep things consistent uppercase all of the bounds
    bounds = df.bounds
    df[bounds.columns.str.upper()] = bounds
    point = df.representative_point()
    df["X"] = point.x
    df["Y"] = point.y
    return df


def __wrangle_dtypes(
    ddf: DaskDataFrame,
) -> DaskDataFrame:
    float32_cols = [
        "EBSHEAR",
        "MEANWIND_1-3kmAGL",
        "MESH",
        "VIL_DENSITY",
        "FLASH_DENSITY",
        "MOTION_EAST",
        "MOTION_SOUTH",
        "MAXLLAZ",
        "P98LLAZ",
        "P98MLAZ",
        "WETBULB_0C_HGT",
        "PWAT",
        "LJA",
        "MINX",
        "MINY",
        "MAXX",
        "MAXY",
        "X",
        "Y",
    ]
    int32_cols = [
        "MLCIN",
    ]
    uint32_cols = [
        "MUCAPE",
        "MLCAPE",
        "SRH01KM",
        "FLASH_RATE",
        "CAPE_M10M30",
        "SIZE",
        "ID",
    ]
    # 0 - 255
    uint8_cols = [
        "PS",
    ]

    ddf[float32_cols] = ddf[float32_cols].astype(np.float32)
    # 32-bit signed integer (``-2_147_483_648`` to ``2_147_483_647``)
    ddf[int32_cols] = ddf[int32_cols].astype(np.int32)
    # 32-bit unsigned integer (``0`` to ``4_294_967_295``)
    ddf[uint32_cols] = ddf[uint32_cols].astype(np.uint32)
    # numpy.uint8`: 8-bit unsigned integer (``0`` to ``255``)
    ddf[uint8_cols] = ddf[uint8_cols].astype(np.uint8)
    return ddf


def to_dask(data: pd.DataFrame, *, chunk_size: int) -> DaskDataFrame:
    return dd.from_pandas(data, chunksize=chunk_size).pipe(wrangle_dtypes)  # type: ignore



def extract(
    path: Path,
    *,
    start: TimeLike,
    end: TimeLike,
    freq: str = "2min",
    chunk_size: int = 256,
) -> None:
    """download and save probsevere data

    Parameters
    ----------
    path : Path
        path to where the file should be save
    start : str or datetime-like
        Left bound for generating dates.
    end : str or datetime-like
        Right bound for generating dates.
    freq : str
        string to step the urls
    name_function : `(n:int) -> str`
        ...
    chunk_size : int; defualt 256
        passed to dask, ...
    """
    drop_columns = ["MAXRC_EMISS", "MAXRC_ICECF", "AVG_BEAM_HGT", "geometry"]
    with Session() as session:
        for timestamp, values in iterdaterange(start, end, freq=freq):
            # create the inital pandas dataframe
            yield (
                # download data
                pd.concat(generate_from_features(session, urls=values["urls"]))
                # wrangle the geometry
                .pipe(wrangle_geometry)
                .drop(columns=drop_columns)
                .pipe(__to_dask, chunk_size=chunk_size)
                # .to_parquet(  # type: ignore
                #     path,
                #     engine="pyarrow",
                #     append=True,
                #     name_function=__name_function(timestamp),
                #     ignore_divisions=True,
                # )
            )

# %%
import requests

VALIDTIME_TEMPLATE = "%Y%m%d_%H%M%S %Z"
data = []
# x = []
base_url = "https://mtarchive.geol.iastate.edu"
# with Session() as session:
# for date in pd.date_range("2022-01-01T00:00", "2022-01-01T00:02", freq="d"):
date = datetime.fromisoformat("2022-01-01")
url = f"{base_url}/{date:%Y}/{date:%m}/{date:%d}/mrms/ncep/ProbSevere/"
r = requests.get(url)
(df,) = pd.read_html(r.text, skiprows=[1, 2], keep_default_na=False)
with Session() as session:
    for file in tuple(url + df.loc[df["Name"] != "", "Name"])[:2]:
        try:
            # with our session make a get request, r is a response object
            r = session.get(file, stream=True)
            # in the event of a non 200 status code we'll raise a HTTPError and trigger the except block
            r.raise_for_status()
        # if there was an error downloading, continue
        except (ConnectionError, HTTPError):
            warn(f"error downloading {url}")
            continue
        fc: FeatureCollection = r.json()
        data.append(fc)
        # r = session.get(url, stream=True)
        # ...
    # print(pd.read_html)
    # r = request
    # print(f"{url}MRMS_PROBSEVERE_{date:%Y}{date:%m}{date:%d}_{date:%H}{date:%M}00.json")
    # url =

    # features = fc["features"]
    # # in the event no storms were record, continue
    # if not features:
    #     # geojson file contained no features
    #     continue

    # df = GeoDataFrame.from_features(features)
    # df["VALIDTIME"] = datetime.strptime(fc["validTime"], VALIDTIME_TEMPLATE)
    # yield df
data
# Out:
# [{'source': 'NOAA/NCEP Central Operations',
#   'product': 'ProbSevere',
#   'validTime': '20220101_000038 UTC',
#   'productionTime': '20220101_000219 UTC',
#   'machine': 'vm-bldr-mrms-ops-probsvr1.ncep.noaa.gov',
#   'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-83.99, 34.73],
#        [-83.93, 34.73],
#        [-83.91, 34.72],
#        [-83.88, 34.69],
#        [-83.88, 34.65],
#        [-83.89, 34.63],
#        [-83.91, 34.62],
#        [-83.93, 34.6],
#        [-83.93, 34.59],
#        [-83.97, 34.57],
#        [-84.01, 34.57],
#        [-84.02, 34.56],
#        [-84.04, 34.56],
#        [-84.08, 34.54],
#        [-84.11, 34.54],
#        [-84.12, 34.55],
#        [-84.12, 34.6],
#        [-84.13, 34.61],
#        [-84.11, 34.62],
#        [-84.08, 34.62],
#        [-84.04, 34.66],
#        [-84.02, 34.71],
#        [-84.01, 34.71],
#        [-83.99, 34.73]]]},
#     'models': {'probsevere': {'PROB': '2',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 2%',
#       'LINE02': '- MESH: 0.04 in.',
#       'LINE03': '- VIL Density: 0.79 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.02 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.005 /s',
#       'LINE07': '- 98% LLAzShear: 0.004 /s',
#       'LINE08': '- 98% MLAzShear: 0.004 /s',
#       'LINE09': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE10': '- EBShear: 49.7 kts; SRH 0-1km AGL: 200 m^2/s^2',
#       'LINE11': '- MUCAPE: 745 J/kg; MLCAPE: 567 J/kg; MLCIN: -5 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 36.8 kts',
#       'LINE13': '- Wetbulb 0C hgt: 9.1 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 207 J/kg; PWAT: 1.4 in.',
#       'LINE15': 'Avg. beam height (ARL): 7.67 kft / 2.34 km'},
#      'probtor': {'PROB': '2',
#       'LINE01': 'ProbTor: 2%',
#       'LINE02': '- Max LLAzShear: 0.005 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.004 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.004 /s (weak)',
#       'LINE05': '- Flash Density: 0.02 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 200 m2/s2',
#       'LINE07': '- EBShear: 49.7 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 36.8 kts',
#       'LINE09': '- MLCAPE/MLCIN: 567/-5 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 7.67 kft / 2.34 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.04 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE05': '- EBShear: 49.7 kts',
#       'LINE06': '- CAPE -10C to -30C: 207 J/kg',
#       'LINE07': '- PWAT: 1.4 in.',
#       'LINE08': '- Wetbulb 0C hgt: 9.1 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.04 in.',
#       'LINE03': '- VIL Density: 0.79 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.004 /s (moderate)',
#       'LINE06': '- 98% MLAzShear: 0.004 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE08': '- EBShear: 49.7 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 36.8 kts',
#       'LINE10': '- MUCAPE: 745 J/kg; MLCAPE: 567 J/kg'}},
#     'properties': {'MUCAPE': '745',
#      'MLCAPE': '567',
#      'MLCIN': '-5',
#      'EBSHEAR': '49.7',
#      'SRH01KM': '200',
#      'MEANWIND_1-3kmAGL': '36.8',
#      'MESH': '0.04',
#      'VIL_DENSITY': '0.79',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.02',
#      'MAXLLAZ': '0.005',
#      'P98LLAZ': '0.004',
#      'P98MLAZ': '0.004',
#      'MAXRC_EMISS': '2336Z 2.6%/min (moderate)',
#      'MAXRC_ICECF': '2226Z 0.0/min (weak)',
#      'WETBULB_0C_HGT': '9.1',
#      'PWAT': '1.4',
#      'CAPE_M10M30': '207',
#      'LJA': '0.0',
#      'SIZE': '306',
#      'AVG_BEAM_HGT': '7.67 kft / 2.34 km',
#      'MOTION_EAST': '12.045',
#      'MOTION_SOUTH': '2.025',
#      'PS': '8',
#      'ID': '20964'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-110.56, 32.8],
#        [-110.52, 32.79],
#        [-110.5, 32.76],
#        [-110.5, 32.74],
#        [-110.47, 32.69],
#        [-110.47, 32.67],
#        [-110.49, 32.65],
#        [-110.52, 32.66],
#        [-110.52, 32.67],
#        [-110.54, 32.69],
#        [-110.55, 32.69],
#        [-110.59, 32.73],
#        [-110.6, 32.75],
#        [-110.59, 32.76],
#        [-110.59, 32.78],
#        [-110.56, 32.8]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.37 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.004 /s',
#       'LINE07': '- 98% LLAzShear: 0.003 /s',
#       'LINE08': '- 98% MLAzShear: 0.003 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 43.7 kts; SRH 0-1km AGL: 85 m^2/s^2',
#       'LINE11': '- MUCAPE: 624 J/kg; MLCAPE: 362 J/kg; MLCIN: -3 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 34.5 kts',
#       'LINE13': '- Wetbulb 0C hgt: 4.2 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 187 J/kg; PWAT: 0.7 in.',
#       'LINE15': 'Avg. beam height (ARL): 3.62 kft / 1.10 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.004 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.003 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.003 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 85 m2/s2',
#       'LINE07': '- EBShear: 43.7 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 34.5 kts',
#       'LINE09': '- MLCAPE/MLCIN: 362/-3 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 3.62 kft / 1.10 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 43.7 kts',
#       'LINE06': '- CAPE -10C to -30C: 187 J/kg',
#       'LINE07': '- PWAT: 0.7 in.',
#       'LINE08': '- Wetbulb 0C hgt: 4.2 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.37 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.003 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.003 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 43.7 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 34.5 kts',
#       'LINE10': '- MUCAPE: 624 J/kg; MLCAPE: 362 J/kg'}},
#     'properties': {'MUCAPE': '624',
#      'MLCAPE': '362',
#      'MLCIN': '-3',
#      'EBSHEAR': '43.7',
#      'SRH01KM': '85',
#      'MEANWIND_1-3kmAGL': '34.5',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.37',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.004',
#      'P98LLAZ': '0.003',
#      'P98MLAZ': '0.003',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '4.2',
#      'PWAT': '0.7',
#      'CAPE_M10M30': '187',
#      'LJA': '0.0',
#      'SIZE': '128',
#      'AVG_BEAM_HGT': '3.62 kft / 1.10 km',
#      'MOTION_EAST': '6.694',
#      'MOTION_SOUTH': '-6.406',
#      'PS': '3',
#      'ID': '21312'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-71.2, 47.99],
#        [-71.19, 47.99],
#        [-71.18, 47.99],
#        [-71.17, 47.98],
#        [-71.16, 47.97],
#        [-71.16, 47.96],
#        [-71.16, 47.95],
#        [-71.16, 47.94],
#        [-71.16, 47.93],
#        [-71.15, 47.92],
#        [-71.14, 47.93],
#        [-71.13, 47.92],
#        [-71.13, 47.91],
#        [-71.12, 47.9],
#        [-71.11, 47.9],
#        [-71.1, 47.9],
#        [-71.09, 47.89],
#        [-71.08, 47.88],
#        [-71.07, 47.88],
#        [-71.06, 47.89],
#        [-71.05, 47.88],
#        [-71.04, 47.88],
#        [-71.03, 47.88],
#        [-71.04, 47.88],
#        [-71.05, 47.88],
#        [-71.06, 47.88],
#        [-71.07, 47.88],
#        [-71.08, 47.88],
#        [-71.09, 47.88],
#        [-71.1, 47.88],
#        [-71.11, 47.88],
#        [-71.12, 47.88],
#        [-71.13, 47.88],
#        [-71.14, 47.88],
#        [-71.15, 47.88],
#        [-71.16, 47.88],
#        [-71.17, 47.88],
#        [-71.17, 47.89],
#        [-71.17, 47.9],
#        [-71.17, 47.91],
#        [-71.17, 47.92],
#        [-71.17, 47.93],
#        [-71.17, 47.94],
#        [-71.18, 47.95],
#        [-71.19, 47.95],
#        [-71.2, 47.96],
#        [-71.2, 47.97],
#        [-71.2, 47.98],
#        [-71.2, 47.99]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 0%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.18 in.',
#       'LINE03': '- VIL Density: 0.94 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.000 /s',
#       'LINE07': '- 98% LLAzShear: 0.000 /s',
#       'LINE08': '- 98% MLAzShear: 0.000 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 0.0 kts; SRH 0-1km AGL: 168 m^2/s^2',
#       'LINE11': '- MUCAPE: 0 J/kg; MLCAPE: 0 J/kg; MLCIN: 0 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 31.2 kts',
#       'LINE13': '- Wetbulb 0C hgt: 0.4 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 0 J/kg; PWAT: 0.3 in.',
#       'LINE15': 'Avg. beam height (ARL): 39.44 kft / 12.02 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.000 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 168 m2/s2',
#       'LINE07': '- EBShear: 0.0 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 31.2 kts',
#       'LINE09': '- MLCAPE/MLCIN: 0/0 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 39.44 kft / 12.02 km'},
#      'probhail': {'PROB': '0',
#       'LINE01': 'ProbHail: 0%',
#       'LINE02': '- MESH: 0.18 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 0.0 kts',
#       'LINE06': '- CAPE -10C to -30C: 0 J/kg',
#       'LINE07': '- PWAT: 0.3 in.',
#       'LINE08': '- Wetbulb 0C hgt: 0.4 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.18 in.',
#       'LINE03': '- VIL Density: 0.94 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 0.0 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 31.2 kts',
#       'LINE10': '- MUCAPE: 0 J/kg; MLCAPE: 0 J/kg'}},
#     'properties': {'MUCAPE': '0',
#      'MLCAPE': '0',
#      'MLCIN': '0',
#      'EBSHEAR': '0.0',
#      'SRH01KM': '168',
#      'MEANWIND_1-3kmAGL': '31.2',
#      'MESH': '0.18',
#      'VIL_DENSITY': '0.94',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.000',
#      'P98LLAZ': '0.000',
#      'P98MLAZ': '0.000',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '0.4',
#      'PWAT': '0.3',
#      'CAPE_M10M30': '0',
#      'LJA': '0.0',
#      'SIZE': '68',
#      'AVG_BEAM_HGT': '39.44 kft / 12.02 km',
#      'MOTION_EAST': '7.784',
#      'MOTION_SOUTH': '-2.636',
#      'PS': '0',
#      'ID': '21320'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-110.41, 32.94],
#        [-110.38, 32.94],
#        [-110.35, 32.92],
#        [-110.33, 32.92],
#        [-110.32, 32.9],
#        [-110.32, 32.87],
#        [-110.34, 32.84],
#        [-110.36, 32.84],
#        [-110.37, 32.83],
#        [-110.42, 32.83],
#        [-110.44, 32.85],
#        [-110.45, 32.87],
#        [-110.45, 32.92],
#        [-110.41, 32.94]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.41 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.001 /s',
#       'LINE07': '- 98% LLAzShear: 0.001 /s',
#       'LINE08': '- 98% MLAzShear: 0.001 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 43.2 kts; SRH 0-1km AGL: 84 m^2/s^2',
#       'LINE11': '- MUCAPE: 595 J/kg; MLCAPE: 325 J/kg; MLCIN: -3 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 35.1 kts',
#       'LINE13': '- Wetbulb 0C hgt: 3.5 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 169 J/kg; PWAT: 0.7 in.',
#       'LINE15': 'Avg. beam height (ARL): 4.80 kft / 1.46 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.001 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.001 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 84 m2/s2',
#       'LINE07': '- EBShear: 43.2 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 35.1 kts',
#       'LINE09': '- MLCAPE/MLCIN: 325/-3 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 4.80 kft / 1.46 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 43.2 kts',
#       'LINE06': '- CAPE -10C to -30C: 169 J/kg',
#       'LINE07': '- PWAT: 0.7 in.',
#       'LINE08': '- Wetbulb 0C hgt: 3.5 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.41 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.001 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 43.2 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 35.1 kts',
#       'LINE10': '- MUCAPE: 595 J/kg; MLCAPE: 325 J/kg'}},
#     'properties': {'MUCAPE': '595',
#      'MLCAPE': '325',
#      'MLCIN': '-3',
#      'EBSHEAR': '43.2',
#      'SRH01KM': '84',
#      'MEANWIND_1-3kmAGL': '35.1',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.41',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.001',
#      'P98LLAZ': '0.001',
#      'P98MLAZ': '0.001',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '3.5',
#      'PWAT': '0.7',
#      'CAPE_M10M30': '169',
#      'LJA': '0.0',
#      'SIZE': '135',
#      'AVG_BEAM_HGT': '4.80 kft / 1.46 km',
#      'MOTION_EAST': '8.284',
#      'MOTION_SOUTH': '-4.549',
#      'PS': '3',
#      'ID': '21323'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-96.06, 39.85],
#        [-95.98, 39.85],
#        [-95.98, 39.77],
#        [-96.06, 39.77],
#        [-96.06, 39.85]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 0%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.27 in.',
#       'LINE03': '- VIL Density: 0.51 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.000 /s',
#       'LINE07': '- 98% LLAzShear: 0.000 /s',
#       'LINE08': '- 98% MLAzShear: 0.000 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 0.0 kts; SRH 0-1km AGL: 150 m^2/s^2',
#       'LINE11': '- MUCAPE: 0 J/kg; MLCAPE: 9 J/kg; MLCIN: 0 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 35.5 kts',
#       'LINE13': '- Wetbulb 0C hgt: 0.3 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 0 J/kg; PWAT: 0.4 in.',
#       'LINE15': 'Avg. beam height (ARL): 3.53 kft / 1.07 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.000 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 150 m2/s2',
#       'LINE07': '- EBShear: 0.0 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 35.5 kts',
#       'LINE09': '- MLCAPE/MLCIN: 9/0 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 3.53 kft / 1.07 km'},
#      'probhail': {'PROB': '0',
#       'LINE01': 'ProbHail: 0%',
#       'LINE02': '- MESH: 0.27 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 0.0 kts',
#       'LINE06': '- CAPE -10C to -30C: 0 J/kg',
#       'LINE07': '- PWAT: 0.4 in.',
#       'LINE08': '- Wetbulb 0C hgt: 0.3 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.27 in.',
#       'LINE03': '- VIL Density: 0.51 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 0.0 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 35.5 kts',
#       'LINE10': '- MUCAPE: 0 J/kg; MLCAPE: 9 J/kg'}},
#     'properties': {'MUCAPE': '0',
#      'MLCAPE': '9',
#      'MLCIN': '0',
#      'EBSHEAR': '0.0',
#      'SRH01KM': '150',
#      'MEANWIND_1-3kmAGL': '35.5',
#      'MESH': '0.27',
#      'VIL_DENSITY': '0.51',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.000',
#      'P98LLAZ': '0.000',
#      'P98MLAZ': '0.000',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '0.3',
#      'PWAT': '0.4',
#      'CAPE_M10M30': '0',
#      'LJA': '0.0',
#      'SIZE': '69',
#      'AVG_BEAM_HGT': '3.53 kft / 1.07 km',
#      'MOTION_EAST': '7.784',
#      'MOTION_SOUTH': '-2.636',
#      'PS': '0',
#      'ID': '21324'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-119.77, 38.07],
#        [-119.69, 38.07],
#        [-119.69, 37.98],
#        [-119.77, 37.98],
#        [-119.77, 38.07]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 0%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.08 in.',
#       'LINE03': '- VIL Density: 0.15 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.000 /s',
#       'LINE07': '- 98% LLAzShear: 0.000 /s',
#       'LINE08': '- 98% MLAzShear: 0.000 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 0.0 kts; SRH 0-1km AGL: 87 m^2/s^2',
#       'LINE11': '- MUCAPE: 0 J/kg; MLCAPE: 1 J/kg; MLCIN: 0 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 47.0 kts',
#       'LINE13': '- Wetbulb 0C hgt: 0.4 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 0 J/kg; PWAT: 0.1 in.',
#       'LINE15': 'Avg. beam height (ARL): 10.42 kft / 3.17 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.000 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 87 m2/s2',
#       'LINE07': '- EBShear: 0.0 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 47.0 kts',
#       'LINE09': '- MLCAPE/MLCIN: 1/0 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 10.42 kft / 3.17 km'},
#      'probhail': {'PROB': '0',
#       'LINE01': 'ProbHail: 0%',
#       'LINE02': '- MESH: 0.08 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 0.0 kts',
#       'LINE06': '- CAPE -10C to -30C: 0 J/kg',
#       'LINE07': '- PWAT: 0.1 in.',
#       'LINE08': '- Wetbulb 0C hgt: 0.4 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.08 in.',
#       'LINE03': '- VIL Density: 0.15 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 0.0 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 47.0 kts',
#       'LINE10': '- MUCAPE: 0 J/kg; MLCAPE: 1 J/kg'}},
#     'properties': {'MUCAPE': '0',
#      'MLCAPE': '1',
#      'MLCIN': '0',
#      'EBSHEAR': '0.0',
#      'SRH01KM': '87',
#      'MEANWIND_1-3kmAGL': '47.0',
#      'MESH': '0.08',
#      'VIL_DENSITY': '0.15',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.000',
#      'P98LLAZ': '0.000',
#      'P98MLAZ': '0.000',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '0.4',
#      'PWAT': '0.1',
#      'CAPE_M10M30': '0',
#      'LJA': '0.0',
#      'SIZE': '90',
#      'AVG_BEAM_HGT': '10.42 kft / 3.17 km',
#      'MOTION_EAST': '7.784',
#      'MOTION_SOUTH': '-2.636',
#      'PS': '0',
#      'ID': '21328'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-75.98, 36.74],
#        [-75.89, 36.74],
#        [-75.89, 36.66],
#        [-75.98, 36.66],
#        [-75.98, 36.74]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 0%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.06 in.',
#       'LINE03': '- VIL Density: 0.43 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.000 /s',
#       'LINE07': '- 98% LLAzShear: 0.000 /s',
#       'LINE08': '- 98% MLAzShear: 0.000 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 23.1 kts; SRH 0-1km AGL: 146 m^2/s^2',
#       'LINE11': '- MUCAPE: 25 J/kg; MLCAPE: 0 J/kg; MLCIN: 0 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 30.3 kts',
#       'LINE13': '- Wetbulb 0C hgt: 8.3 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 0 J/kg; PWAT: 0.9 in.',
#       'LINE15': 'Avg. beam height (ARL): 5.40 kft / 1.65 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.000 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 146 m2/s2',
#       'LINE07': '- EBShear: 23.1 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 30.3 kts',
#       'LINE09': '- MLCAPE/MLCIN: 0/0 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 5.40 kft / 1.65 km'},
#      'probhail': {'PROB': '0',
#       'LINE01': 'ProbHail: 0%',
#       'LINE02': '- MESH: 0.06 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 23.1 kts',
#       'LINE06': '- CAPE -10C to -30C: 0 J/kg',
#       'LINE07': '- PWAT: 0.9 in.',
#       'LINE08': '- Wetbulb 0C hgt: 8.3 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.06 in.',
#       'LINE03': '- VIL Density: 0.43 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 23.1 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 30.3 kts',
#       'LINE10': '- MUCAPE: 25 J/kg; MLCAPE: 0 J/kg'}},
#     'properties': {'MUCAPE': '25',
#      'MLCAPE': '0',
#      'MLCIN': '0',
#      'EBSHEAR': '23.1',
#      'SRH01KM': '146',
#      'MEANWIND_1-3kmAGL': '30.3',
#      'MESH': '0.06',
#      'VIL_DENSITY': '0.43',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.000',
#      'P98LLAZ': '0.000',
#      'P98MLAZ': '0.000',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '8.3',
#      'PWAT': '0.9',
#      'CAPE_M10M30': '0',
#      'LJA': '0.0',
#      'SIZE': '90',
#      'AVG_BEAM_HGT': '5.40 kft / 1.65 km',
#      'MOTION_EAST': '7.784',
#      'MOTION_SOUTH': '-2.636',
#      'PS': '0',
#      'ID': '21329'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-111.12, 33.3],
#        [-111.09, 33.3],
#        [-111.07, 33.29],
#        [-111.07, 33.28],
#        [-111.05, 33.26],
#        [-111.05, 33.12],
#        [-111.07, 33.09],
#        [-111.1, 33.11],
#        [-111.14, 33.11],
#        [-111.18, 33.15],
#        [-111.18, 33.19],
#        [-111.15, 33.23],
#        [-111.13, 33.27],
#        [-111.13, 33.29],
#        [-111.12, 33.3]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 0%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.70 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.002 /s',
#       'LINE07': '- 98% LLAzShear: 0.002 /s',
#       'LINE08': '- 98% MLAzShear: 0.001 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 23.4 kts; SRH 0-1km AGL: 48 m^2/s^2',
#       'LINE11': '- MUCAPE: 314 J/kg; MLCAPE: 166 J/kg; MLCIN: -4 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 19.0 kts',
#       'LINE13': '- Wetbulb 0C hgt: 5.7 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 74 J/kg; PWAT: 0.8 in.',
#       'LINE15': 'Avg. beam height (ARL): 2.11 kft / 0.64 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.002 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.002 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 48 m2/s2',
#       'LINE07': '- EBShear: 23.4 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 19.0 kts',
#       'LINE09': '- MLCAPE/MLCIN: 166/-4 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 2.11 kft / 0.64 km'},
#      'probhail': {'PROB': '0',
#       'LINE01': 'ProbHail: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 23.4 kts',
#       'LINE06': '- CAPE -10C to -30C: 74 J/kg',
#       'LINE07': '- PWAT: 0.8 in.',
#       'LINE08': '- Wetbulb 0C hgt: 5.7 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.70 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.002 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 23.4 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 19.0 kts',
#       'LINE10': '- MUCAPE: 314 J/kg; MLCAPE: 166 J/kg'}},
#     'properties': {'MUCAPE': '314',
#      'MLCAPE': '166',
#      'MLCIN': '-4',
#      'EBSHEAR': '23.4',
#      'SRH01KM': '48',
#      'MEANWIND_1-3kmAGL': '19.0',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.70',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.002',
#      'P98LLAZ': '0.002',
#      'P98MLAZ': '0.001',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '5.7',
#      'PWAT': '0.8',
#      'CAPE_M10M30': '74',
#      'LJA': '0.0',
#      'SIZE': '226',
#      'AVG_BEAM_HGT': '2.11 kft / 0.64 km',
#      'MOTION_EAST': '8.913',
#      'MOTION_SOUTH': '-4.906',
#      'PS': '0',
#      'ID': '21330'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-110.99, 33.08],
#        [-110.94, 33.06],
#        [-110.9, 33.02],
#        [-110.9, 33.0],
#        [-110.89, 32.99],
#        [-110.89, 32.9],
#        [-110.88, 32.89],
#        [-110.88, 32.86],
#        [-110.89, 32.85],
#        [-110.89, 32.82],
#        [-110.92, 32.79],
#        [-110.98, 32.79],
#        [-111.0, 32.81],
#        [-111.0, 32.98],
#        [-111.01, 32.99],
#        [-111.01, 33.07],
#        [-110.99, 33.08]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.75 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.002 /s',
#       'LINE07': '- 98% LLAzShear: 0.001 /s',
#       'LINE08': '- 98% MLAzShear: 0.001 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 31.7 kts; SRH 0-1km AGL: 80 m^2/s^2',
#       'LINE11': '- MUCAPE: 401 J/kg; MLCAPE: 305 J/kg; MLCIN: -6 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 24.9 kts',
#       'LINE13': '- Wetbulb 0C hgt: 4.8 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 116 J/kg; PWAT: 0.8 in.',
#       'LINE15': 'Avg. beam height (ARL): 3.42 kft / 1.04 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.002 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.001 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 80 m2/s2',
#       'LINE07': '- EBShear: 31.7 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 24.9 kts',
#       'LINE09': '- MLCAPE/MLCIN: 305/-6 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 3.42 kft / 1.04 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 31.7 kts',
#       'LINE06': '- CAPE -10C to -30C: 116 J/kg',
#       'LINE07': '- PWAT: 0.8 in.',
#       'LINE08': '- Wetbulb 0C hgt: 4.8 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.75 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.001 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 31.7 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 24.9 kts',
#       'LINE10': '- MUCAPE: 401 J/kg; MLCAPE: 305 J/kg'}},
#     'properties': {'MUCAPE': '401',
#      'MLCAPE': '305',
#      'MLCIN': '-6',
#      'EBSHEAR': '31.7',
#      'SRH01KM': '80',
#      'MEANWIND_1-3kmAGL': '24.9',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.75',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.002',
#      'P98LLAZ': '0.001',
#      'P98MLAZ': '0.001',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '4.8',
#      'PWAT': '0.8',
#      'CAPE_M10M30': '116',
#      'LJA': '0.0',
#      'SIZE': '330',
#      'AVG_BEAM_HGT': '3.42 kft / 1.04 km',
#      'MOTION_EAST': '8.159',
#      'MOTION_SOUTH': '-3.177',
#      'PS': '1',
#      'ID': '21331'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-82.75, 34.65],
#        [-82.72, 34.65],
#        [-82.71, 34.64],
#        [-82.71, 34.59],
#        [-82.73, 34.59],
#        [-82.74, 34.58],
#        [-82.76, 34.58],
#        [-82.77, 34.59],
#        [-82.77, 34.63],
#        [-82.75, 34.65]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.57 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.005 /s',
#       'LINE07': '- 98% LLAzShear: 0.005 /s',
#       'LINE08': '- 98% MLAzShear: 0.002 /s',
#       'LINE09': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE10': '- EBShear: 52.4 kts; SRH 0-1km AGL: 184 m^2/s^2',
#       'LINE11': '- MUCAPE: 951 J/kg; MLCAPE: 264 J/kg; MLCIN: -44 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 36.5 kts',
#       'LINE13': '- Wetbulb 0C hgt: 10.4 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 196 J/kg; PWAT: 1.6 in.',
#       'LINE15': 'Avg. beam height (ARL): 2.14 kft / 0.65 km'},
#      'probtor': {'PROB': '1',
#       'LINE01': 'ProbTor: 1%',
#       'LINE02': '- Max LLAzShear: 0.005 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.005 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.002 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 184 m2/s2',
#       'LINE07': '- EBShear: 52.4 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 36.5 kts',
#       'LINE09': '- MLCAPE/MLCIN: 264/-44 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 2.14 kft / 0.65 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE05': '- EBShear: 52.4 kts',
#       'LINE06': '- CAPE -10C to -30C: 196 J/kg',
#       'LINE07': '- PWAT: 1.6 in.',
#       'LINE08': '- Wetbulb 0C hgt: 10.4 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.57 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.005 /s (moderate)',
#       'LINE06': '- 98% MLAzShear: 0.002 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE08': '- EBShear: 52.4 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 36.5 kts',
#       'LINE10': '- MUCAPE: 951 J/kg; MLCAPE: 264 J/kg'}},
#     'properties': {'MUCAPE': '951',
#      'MLCAPE': '264',
#      'MLCIN': '-44',
#      'EBSHEAR': '52.4',
#      'SRH01KM': '184',
#      'MEANWIND_1-3kmAGL': '36.5',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.57',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.005',
#      'P98LLAZ': '0.005',
#      'P98MLAZ': '0.002',
#      'MAXRC_EMISS': '2336Z 2.6%/min (moderate)',
#      'MAXRC_ICECF': '2226Z 0.0/min (weak)',
#      'WETBULB_0C_HGT': '10.4',
#      'PWAT': '1.6',
#      'CAPE_M10M30': '196',
#      'LJA': '0.0',
#      'SIZE': '48',
#      'AVG_BEAM_HGT': '2.14 kft / 0.65 km',
#      'MOTION_EAST': '11.923',
#      'MOTION_SOUTH': '1.83',
#      'PS': '7',
#      'ID': '21332'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-110.34, 31.67],
#        [-110.31, 31.67],
#        [-110.29, 31.66],
#        [-110.25, 31.62],
#        [-110.24, 31.6],
#        [-110.24, 31.57],
#        [-110.25, 31.56],
#        [-110.33, 31.56],
#        [-110.37, 31.58],
#        [-110.38, 31.63],
#        [-110.37, 31.65],
#        [-110.34, 31.67]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.33 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.002 /s',
#       'LINE07': '- 98% LLAzShear: 0.002 /s',
#       'LINE08': '- 98% MLAzShear: 0.001 /s',
#       'LINE09': '- Norm. vert. growth rate: 2331Z 1.6%/min (weak)',
#       'LINE10': '- EBShear: 38.9 kts; SRH 0-1km AGL: 120 m^2/s^2',
#       'LINE11': '- MUCAPE: 208 J/kg; MLCAPE: 96 J/kg; MLCIN: -4 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 42.4 kts',
#       'LINE13': '- Wetbulb 0C hgt: 2.4 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 54 J/kg; PWAT: 0.5 in.',
#       'LINE15': 'Avg. beam height (ARL): 1.40 kft / 0.43 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.002 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.002 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 120 m2/s2',
#       'LINE07': '- EBShear: 38.9 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 42.4 kts',
#       'LINE09': '- MLCAPE/MLCIN: 96/-4 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 1.40 kft / 0.43 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: 2331Z 1.6%/min (weak)',
#       'LINE05': '- EBShear: 38.9 kts',
#       'LINE06': '- CAPE -10C to -30C: 54 J/kg',
#       'LINE07': '- PWAT: 0.5 in.',
#       'LINE08': '- Wetbulb 0C hgt: 2.4 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.33 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.002 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: 2331Z 1.6%/min (weak)',
#       'LINE08': '- EBShear: 38.9 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 42.4 kts',
#       'LINE10': '- MUCAPE: 208 J/kg; MLCAPE: 96 J/kg'}},
#     'properties': {'MUCAPE': '208',
#      'MLCAPE': '96',
#      'MLCIN': '-4',
#      'EBSHEAR': '38.9',
#      'SRH01KM': '120',
#      'MEANWIND_1-3kmAGL': '42.4',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.33',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.002',
#      'P98LLAZ': '0.002',
#      'P98MLAZ': '0.001',
#      'MAXRC_EMISS': '2331Z 1.6%/min (weak)',
#      'MAXRC_ICECF': '2336Z 0.0/min (weak)',
#      'WETBULB_0C_HGT': '2.4',
#      'PWAT': '0.5',
#      'CAPE_M10M30': '54',
#      'LJA': '0.0',
#      'SIZE': '137',
#      'AVG_BEAM_HGT': '1.40 kft / 0.43 km',
#      'MOTION_EAST': '7.784',
#      'MOTION_SOUTH': '-2.636',
#      'PS': '2',
#      'ID': '21333'}}]},
#  {'source': 'NOAA/NCEP Central Operations',
#   'product': 'ProbSevere',
#   'validTime': '20220101_000244 UTC',
#   'productionTime': '20220101_000404 UTC',
#   'machine': 'vm-bldr-mrms-ops-probsvr1.ncep.noaa.gov',
#   'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-83.97, 34.73],
#        [-83.92, 34.73],
#        [-83.87, 34.69],
#        [-83.87, 34.65],
#        [-83.88, 34.63],
#        [-83.9, 34.62],
#        [-83.94, 34.58],
#        [-83.98, 34.56],
#        [-84.0, 34.56],
#        [-84.01, 34.55],
#        [-84.1, 34.55],
#        [-84.1, 34.59],
#        [-84.11, 34.6],
#        [-84.11, 34.62],
#        [-84.05, 34.63],
#        [-84.03, 34.65],
#        [-84.01, 34.7],
#        [-83.97, 34.73]]]},
#     'models': {'probsevere': {'PROB': '2',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 2%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.79 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.02 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.005 /s',
#       'LINE07': '- 98% LLAzShear: 0.004 /s',
#       'LINE08': '- 98% MLAzShear: 0.004 /s',
#       'LINE09': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE10': '- EBShear: 49.7 kts; SRH 0-1km AGL: 200 m^2/s^2',
#       'LINE11': '- MUCAPE: 748 J/kg; MLCAPE: 568 J/kg; MLCIN: -6 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 36.8 kts',
#       'LINE13': '- Wetbulb 0C hgt: 9.1 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 207 J/kg; PWAT: 1.4 in.',
#       'LINE15': 'Avg. beam height (ARL): 7.71 kft / 2.35 km'},
#      'probtor': {'PROB': '2',
#       'LINE01': 'ProbTor: 2%',
#       'LINE02': '- Max LLAzShear: 0.005 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.004 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.004 /s (weak)',
#       'LINE05': '- Flash Density: 0.02 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 200 m2/s2',
#       'LINE07': '- EBShear: 49.7 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 36.8 kts',
#       'LINE09': '- MLCAPE/MLCIN: 568/-6 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 7.71 kft / 2.35 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE05': '- EBShear: 49.7 kts',
#       'LINE06': '- CAPE -10C to -30C: 207 J/kg',
#       'LINE07': '- PWAT: 1.4 in.',
#       'LINE08': '- Wetbulb 0C hgt: 9.1 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.79 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.004 /s (moderate)',
#       'LINE06': '- 98% MLAzShear: 0.004 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE08': '- EBShear: 49.7 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 36.8 kts',
#       'LINE10': '- MUCAPE: 748 J/kg; MLCAPE: 568 J/kg'}},
#     'properties': {'MUCAPE': '748',
#      'MLCAPE': '568',
#      'MLCIN': '-6',
#      'EBSHEAR': '49.7',
#      'SRH01KM': '200',
#      'MEANWIND_1-3kmAGL': '36.8',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.79',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.02',
#      'MAXLLAZ': '0.005',
#      'P98LLAZ': '0.004',
#      'P98MLAZ': '0.004',
#      'MAXRC_EMISS': '2336Z 2.6%/min (moderate)',
#      'MAXRC_ICECF': '2226Z 0.0/min (weak)',
#      'WETBULB_0C_HGT': '9.1',
#      'PWAT': '1.4',
#      'CAPE_M10M30': '207',
#      'LJA': '0.0',
#      'SIZE': '297',
#      'AVG_BEAM_HGT': '7.71 kft / 2.35 km',
#      'MOTION_EAST': '9.417',
#      'MOTION_SOUTH': '4.279',
#      'PS': '6',
#      'ID': '20964'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-110.56, 32.8],
#        [-110.52, 32.79],
#        [-110.49, 32.74],
#        [-110.49, 32.72],
#        [-110.47, 32.69],
#        [-110.47, 32.67],
#        [-110.49, 32.65],
#        [-110.52, 32.66],
#        [-110.52, 32.67],
#        [-110.54, 32.69],
#        [-110.55, 32.69],
#        [-110.59, 32.73],
#        [-110.6, 32.75],
#        [-110.59, 32.76],
#        [-110.59, 32.78],
#        [-110.56, 32.8]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.39 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.004 /s',
#       'LINE07': '- 98% LLAzShear: 0.003 /s',
#       'LINE08': '- 98% MLAzShear: 0.003 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 43.7 kts; SRH 0-1km AGL: 85 m^2/s^2',
#       'LINE11': '- MUCAPE: 624 J/kg; MLCAPE: 362 J/kg; MLCIN: -3 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 34.5 kts',
#       'LINE13': '- Wetbulb 0C hgt: 4.2 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 187 J/kg; PWAT: 0.7 in.',
#       'LINE15': 'Avg. beam height (ARL): 3.63 kft / 1.11 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.004 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.003 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.003 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 85 m2/s2',
#       'LINE07': '- EBShear: 43.7 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 34.5 kts',
#       'LINE09': '- MLCAPE/MLCIN: 362/-3 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 3.63 kft / 1.11 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 43.7 kts',
#       'LINE06': '- CAPE -10C to -30C: 187 J/kg',
#       'LINE07': '- PWAT: 0.7 in.',
#       'LINE08': '- Wetbulb 0C hgt: 4.2 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.39 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.003 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.003 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 43.7 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 34.5 kts',
#       'LINE10': '- MUCAPE: 624 J/kg; MLCAPE: 362 J/kg'}},
#     'properties': {'MUCAPE': '624',
#      'MLCAPE': '362',
#      'MLCIN': '-3',
#      'EBSHEAR': '43.7',
#      'SRH01KM': '85',
#      'MEANWIND_1-3kmAGL': '34.5',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.39',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.004',
#      'P98LLAZ': '0.003',
#      'P98MLAZ': '0.003',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '4.2',
#      'PWAT': '0.7',
#      'CAPE_M10M30': '187',
#      'LJA': '0.0',
#      'SIZE': '129',
#      'AVG_BEAM_HGT': '3.63 kft / 1.11 km',
#      'MOTION_EAST': '5.578',
#      'MOTION_SOUTH': '-5.679',
#      'PS': '3',
#      'ID': '21312'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-71.2, 47.99],
#        [-71.19, 47.99],
#        [-71.18, 47.99],
#        [-71.17, 47.98],
#        [-71.16, 47.97],
#        [-71.16, 47.96],
#        [-71.16, 47.95],
#        [-71.16, 47.94],
#        [-71.16, 47.93],
#        [-71.15, 47.92],
#        [-71.14, 47.93],
#        [-71.13, 47.92],
#        [-71.13, 47.91],
#        [-71.12, 47.9],
#        [-71.11, 47.9],
#        [-71.1, 47.9],
#        [-71.09, 47.89],
#        [-71.08, 47.88],
#        [-71.07, 47.88],
#        [-71.06, 47.89],
#        [-71.05, 47.88],
#        [-71.04, 47.88],
#        [-71.03, 47.88],
#        [-71.04, 47.88],
#        [-71.05, 47.88],
#        [-71.06, 47.88],
#        [-71.07, 47.88],
#        [-71.08, 47.88],
#        [-71.09, 47.88],
#        [-71.1, 47.88],
#        [-71.11, 47.88],
#        [-71.12, 47.88],
#        [-71.13, 47.88],
#        [-71.14, 47.88],
#        [-71.15, 47.88],
#        [-71.16, 47.88],
#        [-71.17, 47.88],
#        [-71.17, 47.89],
#        [-71.17, 47.9],
#        [-71.17, 47.91],
#        [-71.17, 47.92],
#        [-71.17, 47.93],
#        [-71.17, 47.94],
#        [-71.18, 47.95],
#        [-71.19, 47.95],
#        [-71.2, 47.96],
#        [-71.2, 47.97],
#        [-71.2, 47.98],
#        [-71.2, 47.99]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 0%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.54 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.000 /s',
#       'LINE07': '- 98% LLAzShear: 0.000 /s',
#       'LINE08': '- 98% MLAzShear: 0.000 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 0.0 kts; SRH 0-1km AGL: 168 m^2/s^2',
#       'LINE11': '- MUCAPE: 0 J/kg; MLCAPE: 0 J/kg; MLCIN: 0 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 31.2 kts',
#       'LINE13': '- Wetbulb 0C hgt: 0.4 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 0 J/kg; PWAT: 0.3 in.',
#       'LINE15': 'Avg. beam height (ARL): 39.44 kft / 12.02 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.000 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 168 m2/s2',
#       'LINE07': '- EBShear: 0.0 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 31.2 kts',
#       'LINE09': '- MLCAPE/MLCIN: 0/0 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 39.44 kft / 12.02 km'},
#      'probhail': {'PROB': '0',
#       'LINE01': 'ProbHail: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 0.0 kts',
#       'LINE06': '- CAPE -10C to -30C: 0 J/kg',
#       'LINE07': '- PWAT: 0.3 in.',
#       'LINE08': '- Wetbulb 0C hgt: 0.4 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.54 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 0.0 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 31.2 kts',
#       'LINE10': '- MUCAPE: 0 J/kg; MLCAPE: 0 J/kg'}},
#     'properties': {'MUCAPE': '0',
#      'MLCAPE': '0',
#      'MLCIN': '0',
#      'EBSHEAR': '0.0',
#      'SRH01KM': '168',
#      'MEANWIND_1-3kmAGL': '31.2',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.54',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.000',
#      'P98LLAZ': '0.000',
#      'P98MLAZ': '0.000',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '0.4',
#      'PWAT': '0.3',
#      'CAPE_M10M30': '0',
#      'LJA': '0.0',
#      'SIZE': '68',
#      'AVG_BEAM_HGT': '39.44 kft / 12.02 km',
#      'MOTION_EAST': '7.735',
# ...
#        [-110.88, 32.87],
#        [-110.89, 32.86],
#        [-110.89, 32.83],
#        [-110.92, 32.79],
#        [-110.98, 32.79],
#        [-111.0, 32.81],
#        [-111.0, 32.88],
#        [-110.99, 32.9],
#        [-111.0, 32.91],
#        [-111.0, 32.99],
#        [-111.01, 33.0],
#        [-111.01, 33.06],
#        [-110.99, 33.08]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.82 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.002 /s',
#       'LINE07': '- 98% LLAzShear: 0.001 /s',
#       'LINE08': '- 98% MLAzShear: 0.001 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 31.8 kts; SRH 0-1km AGL: 81 m^2/s^2',
#       'LINE11': '- MUCAPE: 401 J/kg; MLCAPE: 305 J/kg; MLCIN: -6 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 24.9 kts',
#       'LINE13': '- Wetbulb 0C hgt: 4.8 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 116 J/kg; PWAT: 0.8 in.',
#       'LINE15': 'Avg. beam height (ARL): 3.42 kft / 1.04 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.002 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.001 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 81 m2/s2',
#       'LINE07': '- EBShear: 31.8 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 24.9 kts',
#       'LINE09': '- MLCAPE/MLCIN: 305/-6 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 3.42 kft / 1.04 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 31.8 kts',
#       'LINE06': '- CAPE -10C to -30C: 116 J/kg',
#       'LINE07': '- PWAT: 0.8 in.',
#       'LINE08': '- Wetbulb 0C hgt: 4.8 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.82 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.001 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 31.8 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 24.9 kts',
#       'LINE10': '- MUCAPE: 401 J/kg; MLCAPE: 305 J/kg'}},
#     'properties': {'MUCAPE': '401',
#      'MLCAPE': '305',
#      'MLCIN': '-6',
#      'EBSHEAR': '31.8',
#      'SRH01KM': '81',
#      'MEANWIND_1-3kmAGL': '24.9',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.82',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.002',
#      'P98LLAZ': '0.001',
#      'P98MLAZ': '0.001',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '4.8',
#      'PWAT': '0.8',
#      'CAPE_M10M30': '116',
#      'LJA': '0.0',
#      'SIZE': '319',
#      'AVG_BEAM_HGT': '3.42 kft / 1.04 km',
#      'MOTION_EAST': '7.735',
#      'MOTION_SOUTH': '-2.78',
#      'PS': '1',
#      'ID': '21331'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-82.71, 34.66],
#        [-82.68, 34.65],
#        [-82.68, 34.6],
#        [-82.69, 34.59],
#        [-82.73, 34.59],
#        [-82.73, 34.65],
#        [-82.71, 34.66]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.57 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.005 /s',
#       'LINE07': '- 98% LLAzShear: 0.005 /s',
#       'LINE08': '- 98% MLAzShear: 0.002 /s',
#       'LINE09': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE10': '- EBShear: 51.7 kts; SRH 0-1km AGL: 185 m^2/s^2',
#       'LINE11': '- MUCAPE: 940 J/kg; MLCAPE: 264 J/kg; MLCIN: -43 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 36.7 kts',
#       'LINE13': '- Wetbulb 0C hgt: 10.3 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 194 J/kg; PWAT: 1.6 in.',
#       'LINE15': 'Avg. beam height (ARL): 1.99 kft / 0.61 km'},
#      'probtor': {'PROB': '1',
#       'LINE01': 'ProbTor: 1%',
#       'LINE02': '- Max LLAzShear: 0.005 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.005 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.002 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 185 m2/s2',
#       'LINE07': '- EBShear: 51.7 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 36.7 kts',
#       'LINE09': '- MLCAPE/MLCIN: 264/-43 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 1.99 kft / 0.61 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE05': '- EBShear: 51.7 kts',
#       'LINE06': '- CAPE -10C to -30C: 194 J/kg',
#       'LINE07': '- PWAT: 1.6 in.',
#       'LINE08': '- Wetbulb 0C hgt: 10.3 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.57 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.005 /s (moderate)',
#       'LINE06': '- 98% MLAzShear: 0.002 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: 2336Z 2.6%/min (moderate)',
#       'LINE08': '- EBShear: 51.7 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 36.7 kts',
#       'LINE10': '- MUCAPE: 940 J/kg; MLCAPE: 264 J/kg'}},
#     'properties': {'MUCAPE': '940',
#      'MLCAPE': '264',
#      'MLCIN': '-43',
#      'EBSHEAR': '51.7',
#      'SRH01KM': '185',
#      'MEANWIND_1-3kmAGL': '36.7',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.57',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.005',
#      'P98LLAZ': '0.005',
#      'P98MLAZ': '0.002',
#      'MAXRC_EMISS': '2336Z 2.6%/min (moderate)',
#      'MAXRC_ICECF': '2226Z 0.0/min (weak)',
#      'WETBULB_0C_HGT': '10.3',
#      'PWAT': '1.6',
#      'CAPE_M10M30': '194',
#      'LJA': '0.0',
#      'SIZE': '43',
#      'AVG_BEAM_HGT': '1.99 kft / 0.61 km',
#      'MOTION_EAST': '13.301',
#      'MOTION_SOUTH': '0.562',
#      'PS': '7',
#      'ID': '21332'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-110.35, 31.67],
#        [-110.3, 31.67],
#        [-110.25, 31.62],
#        [-110.24, 31.6],
#        [-110.24, 31.57],
#        [-110.25, 31.56],
#        [-110.28, 31.56],
#        [-110.3, 31.55],
#        [-110.31, 31.56],
#        [-110.33, 31.56],
#        [-110.37, 31.58],
#        [-110.38, 31.64],
#        [-110.35, 31.67]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.38 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.002 /s',
#       'LINE07': '- 98% LLAzShear: 0.002 /s',
#       'LINE08': '- 98% MLAzShear: 0.001 /s',
#       'LINE09': '- Norm. vert. growth rate: 2331Z 1.6%/min (weak)',
#       'LINE10': '- EBShear: 39.0 kts; SRH 0-1km AGL: 120 m^2/s^2',
#       'LINE11': '- MUCAPE: 208 J/kg; MLCAPE: 96 J/kg; MLCIN: -4 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 42.4 kts',
#       'LINE13': '- Wetbulb 0C hgt: 2.4 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 54 J/kg; PWAT: 0.5 in.',
#       'LINE15': 'Avg. beam height (ARL): 1.39 kft / 0.43 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.002 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.002 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 120 m2/s2',
#       'LINE07': '- EBShear: 39.0 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 42.4 kts',
#       'LINE09': '- MLCAPE/MLCIN: 96/-4 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 1.39 kft / 0.43 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: 2331Z 1.6%/min (weak)',
#       'LINE05': '- EBShear: 39.0 kts',
#       'LINE06': '- CAPE -10C to -30C: 54 J/kg',
#       'LINE07': '- PWAT: 0.5 in.',
#       'LINE08': '- Wetbulb 0C hgt: 2.4 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.00 in.',
#       'LINE03': '- VIL Density: 0.38 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.002 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.001 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: 2331Z 1.6%/min (weak)',
#       'LINE08': '- EBShear: 39.0 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 42.4 kts',
#       'LINE10': '- MUCAPE: 208 J/kg; MLCAPE: 96 J/kg'}},
#     'properties': {'MUCAPE': '208',
#      'MLCAPE': '96',
#      'MLCIN': '-4',
#      'EBSHEAR': '39.0',
#      'SRH01KM': '120',
#      'MEANWIND_1-3kmAGL': '42.4',
#      'MESH': '0.00',
#      'VIL_DENSITY': '0.38',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.002',
#      'P98LLAZ': '0.002',
#      'P98MLAZ': '0.001',
#      'MAXRC_EMISS': '2331Z 1.6%/min (weak)',
#      'MAXRC_ICECF': '2336Z 0.0/min (weak)',
#      'WETBULB_0C_HGT': '2.4',
#      'PWAT': '0.5',
#      'CAPE_M10M30': '54',
#      'LJA': '0.0',
#      'SIZE': '142',
#      'AVG_BEAM_HGT': '1.39 kft / 0.43 km',
#      'MOTION_EAST': '5.577',
#      'MOTION_SOUTH': '-5.682',
#      'PS': '2',
#      'ID': '21333'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-81.05, 43.76],
#        [-80.97, 43.76],
#        [-80.97, 43.68],
#        [-81.05, 43.68],
#        [-81.05, 43.76]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 0%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.26 in.',
#       'LINE03': '- VIL Density: 0.60 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.00 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.000 /s',
#       'LINE07': '- 98% LLAzShear: 0.000 /s',
#       'LINE08': '- 98% MLAzShear: 0.000 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 0.0 kts; SRH 0-1km AGL: 152 m^2/s^2',
#       'LINE11': '- MUCAPE: 0 J/kg; MLCAPE: 6 J/kg; MLCIN: 0 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 23.8 kts',
#       'LINE13': '- Wetbulb 0C hgt: 1.1 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 0 J/kg; PWAT: 0.3 in.',
#       'LINE15': 'Avg. beam height (ARL): 17.98 kft / 5.48 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.000 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE05': '- Flash Density: 0.00 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 152 m2/s2',
#       'LINE07': '- EBShear: 0.0 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 23.8 kts',
#       'LINE09': '- MLCAPE/MLCIN: 6/0 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 17.98 kft / 5.48 km'},
#      'probhail': {'PROB': '0',
#       'LINE01': 'ProbHail: 0%',
#       'LINE02': '- MESH: 0.26 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 0.0 kts',
#       'LINE06': '- CAPE -10C to -30C: 0 J/kg',
#       'LINE07': '- PWAT: 0.3 in.',
#       'LINE08': '- Wetbulb 0C hgt: 1.1 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.26 in.',
#       'LINE03': '- VIL Density: 0.60 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.000 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.000 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 0.0 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 23.8 kts',
#       'LINE10': '- MUCAPE: 0 J/kg; MLCAPE: 6 J/kg'}},
#     'properties': {'MUCAPE': '0',
#      'MLCAPE': '6',
#      'MLCIN': '0',
#      'EBSHEAR': '0.0',
#      'SRH01KM': '152',
#      'MEANWIND_1-3kmAGL': '23.8',
#      'MESH': '0.26',
#      'VIL_DENSITY': '0.60',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.00',
#      'MAXLLAZ': '0.000',
#      'P98LLAZ': '0.000',
#      'P98MLAZ': '0.000',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '1.1',
#      'PWAT': '0.3',
#      'CAPE_M10M30': '0',
#      'LJA': '0.0',
#      'SIZE': '81',
#      'AVG_BEAM_HGT': '17.98 kft / 5.48 km',
#      'MOTION_EAST': '7.735',
#      'MOTION_SOUTH': '-2.78',
#      'PS': '0',
#      'ID': '21334'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Polygon',
#      'coordinates': [[[-110.0, 32.13],
#        [-109.96, 32.13],
#        [-109.95, 32.1],
#        [-109.97, 32.08],
#        [-109.98, 32.04],
#        [-110.03, 31.99],
#        [-110.06, 31.99],
#        [-110.07, 32.01],
#        [-110.06, 32.05],
#        [-110.03, 32.09],
#        [-110.03, 32.1],
#        [-110.0, 32.13]]]},
#     'models': {'probsevere': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%; ProbWind: 1%; ProbTor: 0%',
#       'LINE02': '- MESH: 0.10 in.',
#       'LINE03': '- VIL Density: 0.58 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- Flash Density (max in last 30 min): 0.03 fl/min/km^2',
#       'LINE06': '- Max LLAzShear: 0.003 /s',
#       'LINE07': '- 98% LLAzShear: 0.002 /s',
#       'LINE08': '- 98% MLAzShear: 0.003 /s',
#       'LINE09': '- Norm. vert. growth rate: N/A',
#       'LINE10': '- EBShear: 46.7 kts; SRH 0-1km AGL: 96 m^2/s^2',
#       'LINE11': '- MUCAPE: 424 J/kg; MLCAPE: 200 J/kg; MLCIN: -7 J/kg',
#       'LINE12': '- MeanWind 1-3kmAGL: 43.1 kts',
#       'LINE13': '- Wetbulb 0C hgt: 3.3 kft AGL',
#       'LINE14': '- CAPE -10C to -30C: 153 J/kg; PWAT: 0.6 in.',
#       'LINE15': 'Avg. beam height (ARL): 2.46 kft / 0.75 km'},
#      'probtor': {'PROB': '0',
#       'LINE01': 'ProbTor: 0%',
#       'LINE02': '- Max LLAzShear: 0.003 /s (weak)',
#       'LINE03': '- 98% LLAzShear: 0.002 /s (weak)',
#       'LINE04': '- 98% MLAzShear: 0.003 /s (weak)',
#       'LINE05': '- Flash Density: 0.03 fl/min/km^2',
#       'LINE06': '- SRH 0-1km AGL: 96 m2/s2',
#       'LINE07': '- EBShear: 46.7 kts',
#       'LINE08': '- MeanWind 1-3kmAGL: 43.1 kts',
#       'LINE09': '- MLCAPE/MLCIN: 200/-7 J/kg',
#       'LINE10': 'Avg. beam height (ARL): 2.46 kft / 0.75 km'},
#      'probhail': {'PROB': '1',
#       'LINE01': 'ProbHail: 1%',
#       'LINE02': '- MESH: 0.10 in.',
#       'LINE03': '- Flash Rate: 0 fl/min',
#       'LINE04': '- Norm. vert. growth rate: N/A',
#       'LINE05': '- EBShear: 46.7 kts',
#       'LINE06': '- CAPE -10C to -30C: 153 J/kg',
#       'LINE07': '- PWAT: 0.6 in.',
#       'LINE08': '- Wetbulb 0C hgt: 3.3 kft AGL'},
#      'probwind': {'PROB': '1',
#       'LINE01': 'ProbWind: 1%',
#       'LINE02': '- MESH: 0.10 in.',
#       'LINE03': '- VIL Density: 0.58 g/m^3',
#       'LINE04': '- Flash Rate: 0 fl/min',
#       'LINE05': '- 98% LLAzShear: 0.002 /s (weak)',
#       'LINE06': '- 98% MLAzShear: 0.003 /s (weak)',
#       'LINE07': '- Norm. vert. growth rate: N/A',
#       'LINE08': '- EBShear: 46.7 kts',
#       'LINE09': '- MeanWind 1-3kmAGL: 43.1 kts',
#       'LINE10': '- MUCAPE: 424 J/kg; MLCAPE: 200 J/kg'}},
#     'properties': {'MUCAPE': '424',
#      'MLCAPE': '200',
#      'MLCIN': '-7',
#      'EBSHEAR': '46.7',
#      'SRH01KM': '96',
#      'MEANWIND_1-3kmAGL': '43.1',
#      'MESH': '0.10',
#      'VIL_DENSITY': '0.58',
#      'FLASH_RATE': '0',
#      'FLASH_DENSITY': '0.03',
#      'MAXLLAZ': '0.003',
#      'P98LLAZ': '0.002',
#      'P98MLAZ': '0.003',
#      'MAXRC_EMISS': 'N/A',
#      'MAXRC_ICECF': 'N/A',
#      'WETBULB_0C_HGT': '3.3',
#      'PWAT': '0.6',
#      'CAPE_M10M30': '153',
#      'LJA': '0.0',
#      'SIZE': '111',
#      'AVG_BEAM_HGT': '2.46 kft / 0.75 km',
#      'MOTION_EAST': '7.659',
#      'MOTION_SOUTH': '-7.452',
#      'PS': '6',
#      'ID': '21335'}}]}]

# %%
from typing import Generic, TypeVar
from geopandas.base import GeometryArray
from geopandas import GeoSeries
import geopandas._vectorized as geov
import pygeos
from numpy.typing import NDArray


from shapely.geometry import GeometryCollection

import warnings

# np.read_html()
float32_cols = [
    "EBSHEAR",
    "MEANWIND_1-3kmAGL",
    "MESH",
    "VIL_DENSITY",
    "FLASH_DENSITY",
    "MOTION_EAST",
    "MOTION_SOUTH",
    "MAXLLAZ",
    "P98LLAZ",
    "P98MLAZ",
    "WETBULB_0C_HGT",
    "PWAT",
    "LJA",
    # "MINX",
    # "MINY",
    # "MAXX",
    # "MAXY",
    # "X",
    # "Y",
]
int32_cols = [
    "MLCIN",
]
uint32_cols = [
    "MUCAPE",
    "MLCAPE",
    "SRH01KM",
    "FLASH_RATE",
    "CAPE_M10M30",
    "SIZE",
    "ID",
]
# 0 - 255
uint8_cols = [
    "PS",
]
all_columns = uint8_cols + uint32_cols + int32_cols + float32_cols



def wrangle_geometry(df: GeoDataFrame) -> pd.DataFrame:
    # to keep things consistent uppercase all of the bounds
    bounds = df.bounds
    df[bounds.columns.str.upper()] = bounds
    with warnings.catch_warnings():
        # /opt/conda/envs/rapids/lib/python3.9/site-packages/geopandas/array.py:524:
        # ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
        #   return GeometryArray(vectorized.representative_point(self.data), crs=self.crs)
        warnings.simplefilter("ignore")
        points = df.representative_point()
    df["Y"] = points.x
    df["X"] = points.y
    return df


def dtypes(ddf: pd.DataFrame):
    float32_cols = [
        "EBSHEAR",
        "MEANWIND_1-3kmAGL",
        "MESH",
        "VIL_DENSITY",
        "FLASH_DENSITY",
        "MOTION_EAST",
        "MOTION_SOUTH",
        "MAXLLAZ",
        "P98LLAZ",
        "P98MLAZ",
        "WETBULB_0C_HGT",
        "PWAT",
        "LJA",
        "MINX",
        "MINY",
        "MAXX",
        "MAXY",
        "X",
        "Y",
    ]
    int32_cols = [
        "MLCIN",
    ]
    uint32_cols = [
        "MUCAPE",
        "MLCAPE",
        "SRH01KM",
        "FLASH_RATE",
        "CAPE_M10M30",
        "SIZE",
        "ID",
    ]
    # 0 - 255
    uint8_cols = [
        "PS",
    ]

    ddf[float32_cols] = ddf[float32_cols].astype(np.float32)
    # 32-bit signed integer (``-2_147_483_648`` to ``2_147_483_647``)
    ddf[int32_cols] = ddf[int32_cols].astype(np.int32)
    # 32-bit unsigned integer (``0`` to ``4_294_967_295``)
    ddf[uint32_cols] = ddf[uint32_cols].astype(np.uint32)
    # numpy.uint8`: 8-bit unsigned integer (``0`` to ``255``)
    ddf[uint8_cols] = ddf[uint8_cols].astype(np.uint8)
    return ddf


import xarray as xr


def transfer(data: Iterable[FeatureCollection]) -> xr.Dataset:
    keys = []

    def generate():
        for fc in data:
            keys.append(datetime.strptime(fc["validTime"], VALIDTIME_TEMPLATE))
            df = GeoDataFrame.from_features(fc["features"], columns=all_columns + ["geometry"])
            df["time"] = datetime.strptime(fc["validTime"], VALIDTIME_TEMPLATE)
            yield df

    df = pd.concat(generate()).set_index("time").pipe(wrangle_geometry).drop(columns="geometry").pipe(dtypes)

    return xr.Dataset.from_dataframe(df)


#
store = Path.cwd().parent / "data/PROBSEVERE"


def main():
    ds = transfer(data)
    zarr_kwargs = {}
    if store.exists():
        zarr_kwargs = {"mode": "a", "append_dim": "time"}

    ds.to_zarr(store, **zarr_kwargs)


main()

# %%
xr.open_zarr(store).to_dataframe().set_index("ID", append=True)
# Out:
#                            CAPE_M10M30    EBSHEAR  FLASH_DENSITY  FLASH_RATE  \
# time                ID
# 2022-01-01 00:00:38 20964          207  49.700001           0.02           0
#                     21312          187  43.700001           0.00           0
#                     21320            0   0.000000           0.00           0
#                     21323          169  43.200001           0.00           0
#                     21324            0   0.000000           0.00           0
#                     21328            0   0.000000           0.00           0
#                     21329            0  23.100000           0.00           0
#                     21330           74  23.400000           0.00           0
#                     21331          116  31.700001           0.00           0
#                     21332          196  52.400002           0.00           0
#                     21333           54  38.900002           0.00           0
# 2022-01-01 00:02:44 20964          207  49.700001           0.02           0
#                     21312          187  43.700001           0.00           0
#                     21320            0   0.000000           0.00           0
#                     21323          169  43.200001           0.00           0
#                     21324            0   0.000000           0.00           0
#                     21328            0   0.000000           0.00           0
#                     21330           74  23.400000           0.00           0
#                     21331          116  31.799999           0.00           0
#                     21332          194  51.700001           0.00           0
#                     21333           54  39.000000           0.00           0
#                     21334            0   0.000000           0.00           0
#                     21335          153  46.700001           0.03           0
#
#                            LJA  MAXLLAZ        MAXX       MAXY  \
# time                ID
# 2022-01-01 00:00:38 20964  0.0    0.005  -83.879997  34.730000
#                     21312  0.0    0.004 -110.470001  32.799999
#                     21320  0.0    0.000  -71.029999  47.990002
#                     21323  0.0    0.001 -110.320000  32.939999
#                     21324  0.0    0.000  -95.980003  39.849998
#                     21328  0.0    0.000 -119.690002  38.070000
#                     21329  0.0    0.000  -75.889999  36.740002
#                     21330  0.0    0.002 -111.050003  33.299999
#                     21331  0.0    0.002 -110.879997  33.080002
#                     21332  0.0    0.005  -82.709999  34.650002
#                     21333  0.0    0.002 -110.239998  31.670000
# 2022-01-01 00:02:44 20964  0.0    0.005  -83.870003  34.730000
#                     21312  0.0    0.004 -110.470001  32.799999
#                     21320  0.0    0.000  -71.029999  47.990002
#                     21323  0.0    0.001 -110.320000  32.939999
#                     21324  0.0    0.000  -95.980003  39.849998
#                     21328  0.0    0.000 -119.690002  38.070000
#                     21330  0.0    0.002 -111.050003  33.299999
#                     21331  0.0    0.002 -110.879997  33.080002
#                     21332  0.0    0.005  -82.680000  34.660000
#                     21333  0.0    0.002 -110.239998  31.670000
#                     21334  0.0    0.000  -80.970001  43.759998
#                     21335  0.0    0.003 -109.949997  32.130001
#
#                            MEANWIND_1-3kmAGL  MESH  ...  P98LLAZ  P98MLAZ  PS  \
# time                ID                              ...
# 2022-01-01 00:00:38 20964          36.799999  0.04  ...    0.004    0.004   8
#                     21312          34.500000  0.00  ...    0.003    0.003   3
#                     21320          31.200001  0.18  ...    0.000    0.000   0
#                     21323          35.099998  0.00  ...    0.001    0.001   3
#                     21324          35.500000  0.27  ...    0.000    0.000   0
#                     21328          47.000000  0.08  ...    0.000    0.000   0
#                     21329          30.299999  0.06  ...    0.000    0.000   0
#                     21330          19.000000  0.00  ...    0.002    0.001   0
#                     21331          24.900000  0.00  ...    0.001    0.001   1
#                     21332          36.500000  0.00  ...    0.005    0.002   7
#                     21333          42.400002  0.00  ...    0.002    0.001   2
# 2022-01-01 00:02:44 20964          36.799999  0.00  ...    0.004    0.004   6
#                     21312          34.500000  0.00  ...    0.003    0.003   3
#                     21320          31.200001  0.00  ...    0.000    0.000   0
#                     21323          35.099998  0.00  ...    0.001    0.001   3
#                     21324          35.500000  0.27  ...    0.000    0.000   0
#                     21328          47.000000  0.08  ...    0.000    0.000   0
#                     21330          19.000000  0.00  ...    0.002    0.001   0
#                     21331          24.900000  0.00  ...    0.001    0.001   1
#                     21332          36.700001  0.00  ...    0.005    0.002   7
#                     21333          42.400002  0.00  ...    0.002    0.001   2
#                     21334          23.799999  0.26  ...    0.000    0.000   0
#                     21335          43.099998  0.10  ...    0.002    0.003   6
#
#                            PWAT  SIZE  SRH01KM  VIL_DENSITY  WETBULB_0C_HGT  \
# time                ID
# 2022-01-01 00:00:38 20964   1.4   306      200         0.79             9.1
#                     21312   0.7   128       85         0.37             4.2
#                     21320   0.3    68      168         0.94             0.4
#                     21323   0.7   135       84         0.41             3.5
#                     21324   0.4    69      150         0.51             0.3
#                     21328   0.1    90       87         0.15             0.4
#                     21329   0.9    90      146         0.43             8.3
#                     21330   0.8   226       48         0.70             5.7
#                     21331   0.8   330       80         0.75             4.8
#                     21332   1.6    48      184         0.57            10.4
#                     21333   0.5   137      120         0.33             2.4
# 2022-01-01 00:02:44 20964   1.4   297      200         0.79             9.1
#                     21312   0.7   129       85         0.39             4.2
#                     21320   0.3    68      168         0.54             0.4
#                     21323   0.7   135       84         0.41             3.5
#                     21324   0.4    69      150         0.51             0.3
#                     21328   0.1    90       87         0.15             0.4
#                     21330   0.8   218       48         0.70             5.7
#                     21331   0.8   319       81         0.82             4.8
#                     21332   1.6    43      185         0.57            10.3
#                     21333   0.5   142      120         0.38             2.4
#                     21334   0.3    81      152         0.60             1.1
#                     21335   0.6   111       96         0.58             3.3
#
#                                    X           Y
# time                ID
# 2022-01-01 00:00:38 20964  34.639999  -83.972504
#                     21312  32.709999 -110.526001
#                     21320  47.935001  -71.165001
#                     21323  32.884998 -110.385002
#                     21324  39.810001  -96.019997
#                     21328  38.025002 -119.730003
#                     21329  36.700001  -75.934998
#                     21330  33.209999 -111.107498
#                     21331  32.939999 -110.945000
#                     21332  34.610001  -82.739998
#                     21333  31.610001 -110.310501
# 2022-01-01 00:02:44 20964  34.639999  -83.957497
#                     21312  32.724998 -110.537498
#                     21320  47.935001  -71.165001
#                     21323  32.884998 -110.385002
#                     21324  39.810001  -96.019997
#                     21328  38.025002 -119.730003
#                     21330  33.220001 -111.104286
#                     21331  32.945000 -110.945000
#                     21332  34.625000  -82.705002
#                     21333  31.610001 -110.309998
#                     21334  43.720001  -81.010002
#                     21335  32.064999 -110.011253
#
# [23 rows x 27 columns]
