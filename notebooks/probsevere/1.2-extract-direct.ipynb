# %%
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import os
import uuid
from pathlib import Path
from warnings import warn
from datetime import datetime
from typing import Callable, Union, TypedDict
import pandas as pd
import numpy as np
import dask.dataframe as dd
from geopandas import GeoDataFrame
from requests import Session, HTTPError

PROBSEVERE_URL_TEMPLATE = (
    "https://mtarchive.geol.iastate.edu/%Y/%m/%d/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_%Y%m%d_%H%M00.json"
)

FILE_OUT_DIR = os.path.abspath("../../dask-parquet")

TimeLike = Union[datetime, str, pd.Timestamp]

class Feature(TypedDict):
    properties:dict[str,Union[float,int,str]]

class FeatureCollection(TypedDict):
    validTime:str
    features:list[Feature]

# %%
__uuid = uuid.uuid4()


def __batch_id(validtime: datetime) -> Callable[[int], str]:
    def wrapper(n: int) -> str:
        return f"probsevere-{n}-{validtime.isoformat(timespec='minutes')}-{__uuid}.parquet"

    return wrapper


def __features(features: list[Feature]) -> pd.DataFrame:
    return GeoDataFrame.from_features(features)


def __bounds(
    df: pd.DataFrame,
    drop_columns: list[str] = ["MAXRC_EMISS", "MAXRC_ICECF", "AVG_BEAM_HGT", "geometry"],
) -> pd.DataFrame:
    return pd.concat((df, df["geometry"].bounds), axis=1).drop(columns=drop_columns)

# %%
def direct_to_parquet(
    path_dir: Path,
    start: TimeLike,
    end: TimeLike,
    freq: str = "2min",
) -> None:
    """scrape data from the iastate archive over a daterange"""

    # create a DatetimeIndex using the the function arguments and format the urls using the url template
    urls = pd.date_range(start=start, end=end, freq=freq)
    # using Session as a context manager
    with Session() as session:
        # iterating over all of the urls
        for url in urls.strftime(PROBSEVERE_URL_TEMPLATE):
            # using a try/catch block in the event the download fails
            try:
                # with our session make a get request, r is a response object
                r = session.get(url, stream=True)
                # in the event of a non 200 status code we'll raise a HTTPError and trigger the except block
                r.raise_for_status()
            # if there was an error downloading, continue
            except (ConnectionError, HTTPError):
                warn(f"error downloading {url}")
                continue
            fc:FeatureCollection = r.json()

            features = fc["features"]
            # in the event no storms were record, continue
            if not features:
                continue
            # 
            df = __features(features).pipe(__bounds).astype(np.float32)

            valid_time = datetime.strptime(fc["validTime"], "%Y%m%d_%H%M%S %Z")
            # set the valid time
            df["valid_time"] = valid_time

            dd.from_pandas(df, chunksize=256).to_parquet(
mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220427_190000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/04/27/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220427_200000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/04/27/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220427_210000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/04/29/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220429_070400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/02/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220502_073400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/02/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220502_120200.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_003400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_021400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_091000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_091400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_091600.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_210800.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_214000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_214200.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_214400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/03/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220503_214600.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_022200.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_022400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_181000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_181200.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_181400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_181600.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_181800.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_182000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_182200.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_182400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_182600.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_182800.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_183000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_183200.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_183400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_183600.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_183800.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_184000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_184200.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_184400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_184600.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_184800.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_185000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/04/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220504_185200.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/05/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220505_030000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/05/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220505_030200.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/05/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220505_030400.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/05/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220505_223000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/05/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220505_225000.json
#   warn(f"error downloading {url}")
# /tmp/ipykernel_18890/1619779334.py:23: UserWarning: error downloading https://mtarchive.geol.iastate.edu/2022/05/11/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220511_133400.json
#   warn(f"error downloading {url}")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18890/1101223761.py in <cell line: 1>()
#       1 if __name__ == "__main__":
# ----> 2     x = direct_to_parquet(
#       3         Path(FILE_OUT_DIR),
#       4         start="2022-03-01T00:00:00Z",
#       5         end="2022-08-4T00:00:00Z",
#
# /tmp/ipykernel_18890/1619779334.py in direct_to_parquet(path_dir, start, end, freq)
#      16             try:
#      17                 # with our session make a get request, r is a response object
# ---> 18                 r = session.get(url, stream=True)
#      19                 # in the event of a non 200 status code we'll raise a HTTPError and trigger the except block
#      20                 r.raise_for_status()
#
# /opt/venv/lib/python3.10/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     598
#     599         kwargs.setdefault("allow_redirects", True)
# --> 600         return self.request("GET", url, **kwargs)
#     601
#     602     def options(self, url, **kwargs):
#
# /opt/venv/lib/python3.10/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# /opt/venv/lib/python3.10/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# /opt/venv/lib/python3.10/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# /opt/venv/lib/python3.10/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# /opt/venv/lib/python3.10/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/venv/lib/python3.10/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/venv/lib/python3.10/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1372         try:
#    1373             try:
# -> 1374                 response.begin()
#    1375             except ConnectionError:
#    1376                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1271                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272                   self.__class__)
# -> 1273             return self.read(nbytes, buffer)
#    1274         else:
#    1275             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1127         try:
#    1128             if buffer is not None:
# -> 1129                 return self._sslobj.read(len, buffer)
#    1130             else:
#    1131                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
